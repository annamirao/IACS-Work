# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import splrep, splev
# %matplotlib inline

# %%
mean = [1, 1, 1, 1]
s =0
cov = [[1, s, 0 , 0], [s, 1, s, 0 ], [0, s, 1, s], [0, 0, s, 1]]
# diagonal covariance?
y = np.random.multivariate_normal(mean, cov, 1).T

arr = np.array([-75, 0, 75])

options = (1, 2, 3, 4, 5)

# for o in options:
    # tck = splrep(x, y, xb=None, xe=None, k=o, t=arr)
    # plt.plot(eval_points, splev(eval_points, tck, der=0), label='degree ' + str(o) + ' piecewise')


plt.figure(figsize=(16,8))
plt.plot( y, '-x')
plt.axis('equal')

plt.show()

# %%
print(cov)
# Out:
# [[1, 1, 0, 0], [1, 1, 1, 0], [0, 1, 1, 1], [0, 0, 1, 1]]
