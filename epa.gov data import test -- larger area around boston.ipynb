# %%
# syntax: from (library) import (specific library function)
from pandas import DataFrame, read_csv

# syntax: import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd 

# Enable inline plotting
# %matplotlib inline

# %%
Location = r'/Users/Annamira/Downloads/AQDM_843819228.txt' 
readDF = pd.read_csv(Location, engine='python')
readDF
# Out:
#                site  data_status  action_code            datetime  parameter  \
# 0      840250250042          0.0         10.0  20150629T0000-0500    43502.0
# 1      840250250042          0.0         10.0  20150629T0000-0500    43502.0
# 2      840250250042          0.0         10.0  20150816T0000-0500    43502.0
# 3      840250250042          0.0         10.0  20150705T0000-0500    43502.0
# 4      840250250042          0.0         10.0  20150705T0000-0500    43502.0
# 5      840250250042          0.0         10.0  20150717T0000-0500    43502.0
# 6      840250250042          0.0         10.0  20150717T0000-0500    43502.0
# 7      840250250042          0.0         10.0  20150605T0000-0500    43502.0
# 8      840250250042          0.0         10.0  20150828T0000-0500    43502.0
# 9      840250250042          0.0         10.0  20150723T0000-0500    43502.0
# 10     840250250042          0.0         10.0  20150915T0000-0500    43502.0
# ...

# %%
# readDF.plot(y=7, use_index=True)
print('number of parameters')
print(len(sorted(set(readDF['parameter'].values))))
# Out:
# number of parameters
# 182

# %%
readDF.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x114678668>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10b639ef0>]], dtype=object)

# %%
readDF.plot(x ='lat', y ='lon',kind='scatter')

# %%
parameters = readDF['parameter'].values
lat = readDF['lat'].values
lon = readDF['lon'].values
print(set(lat))
print(set(lon))
locations = [[42.329500000000003, -71.056061],
             [42.348872999999998, -71.054299999999998],
             [42.363100000000003, -71.082599999999999],
             [42.325185999999995, -71.097162999999995]]
bool_arr = [False, False, False, False]
prev = 43502.0
for i in range(0, 7849):
    if prev != parameters[i]:
        if True in bool_arr:
            print(prev)
        prev = parameters[i]
        bool_arr = [False, False, False, False]
        for j in range(0, 4):
            if [lat[i], lon[i]] == locations[j]:
                bool_arr[j] = True
                #break
    else:
        for j in range(0, 4):
            if [lat[i], lon[i]] == locations[j]:
                bool_arr[j] = True
                #break
# Out:
# {nan, 42.329500000000003, 42.348872999999998, 42.363100000000003, 42.325185999999995}
# {nan, -71.056061, -71.054299999999998, -71.082599999999999, -71.097162999999995}

# %%
# read formaldehyde data from lower roxbury (June, July, August 2015)
Location = r'/Users/Annamira/Downloads/AQDM_843819228.txt' 
DF = pd.read_csv(Location, skipfooter=(13122-29), engine='python')
DF.plot(y=7, use_index=True, label='formaldehyde')
